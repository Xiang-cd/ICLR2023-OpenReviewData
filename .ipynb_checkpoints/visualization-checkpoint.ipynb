# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='darkgrid', context='talk', palette='colorblind')

# %% [markdown]
# ## Keywords

# %%
df = pd.read_csv('paperlist23.tsv', index_col=0, sep='\t')
print('# papers:', len(df))
df.head()
# Out:
# # papers: 4501
#                                                          title  \
# paper_id
# RUzSobdYy0V  Quantifying and Mitigating the Impact of Label...
# N3kGYG3ZcTi  Suppression helps: Lateral Inhibition-inspired...
# tmIiMPl4IPa                Factorized Fourier Neural Operators
# mhnHqRqcjYU  DFPC: Data flow driven pruning of coupled chan...
# sZI1Oj9KBKy  TVSPrune - Pruning Non-discriminative filters ...
#
#                                                     link  \
# paper_id
# RUzSobdYy0V  https://openreview.net/forum?id=RUzSobdYy0V
# N3kGYG3ZcTi  https://openreview.net/forum?id=N3kGYG3ZcTi
# tmIiMPl4IPa  https://openreview.net/forum?id=tmIiMPl4IPa
# mhnHqRqcjYU  https://openreview.net/forum?id=mhnHqRqcjYU
# sZI1Oj9KBKy  https://openreview.net/forum?id=sZI1Oj9KBKy
#
#                                                       keywords  \
# paper_id
# RUzSobdYy0V                                                NaN
# N3kGYG3ZcTi  Lateral Inhibition, Convolutional Neural Networks
# tmIiMPl4IPa  fourier transform, fourier operators, pde, nav...
# mhnHqRqcjYU              Pruning, Data Free, Model Compression
# sZI1Oj9KBKy              Structured pruning, model compression
#
#                                                       abstract
# paper_id
# RUzSobdYy0V  Errors in labels obtained via human annotation...
# N3kGYG3ZcTi  Convolutional neural networks (CNNs) have beco...
# tmIiMPl4IPa  We propose the Factorized Fourier Neural Opera...
# mhnHqRqcjYU  Most structured pruning algorithms achieve sub...
# sZI1Oj9KBKy    Achieving structured, data-free sparsity of ...

# %%
counts = pd.Series(
    ', '.join(df['keywords'].dropna()).lower().replace('-', ' ').replace('networks', 'network').split(',')
).str.strip().value_counts().sort_values(ascending=True)
counts.iloc[-50:].plot.barh(figsize=(8, 12), title='ICLR 2023 Submission Top 50 Keywords')
plt.savefig('asset/keywords23.png', dpi=300, bbox_inches='tight')

# %%
from imageio import imread
from wordcloud import WordCloud

wc = WordCloud(background_color="white", max_words=300, max_font_size=64, 
               width=1280, height=640, random_state=0)
wc.generate_from_frequencies(counts.to_dict())
fig = plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.savefig('asset/wordcloud23.png', dpi=300, bbox_inches='tight')

# %%
from imageio import imread
from wordcloud import WordCloud

logo = imread('asset/logo.png')
wc = WordCloud(background_color="white", max_words=300, max_font_size=64, 
               width=1280, height=640, random_state=0, mask=logo)
wc.generate_from_frequencies(counts.to_dict())
fig = plt.figure(figsize=(16, 8))
plt.imshow(logo)
plt.imshow(wc, interpolation="bilinear", alpha=.75)
plt.axis("off")
plt.savefig('asset/logo_wordcloud23.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Rating Distributions

# %%
ratings = pd.read_csv('ratings.20221112.tsv', sep='\t', index_col=0)
print(ratings.iloc[:, :-1].stack().mean())
ratings.head()
# Out:
# 5.016875631350644
#                0    1    2    3    4   5   6   7   8
# paper_id
# RUzSobdYy0V  5.0  6.0  8.0  NaN  NaN NaN NaN NaN NaN
# N3kGYG3ZcTi  3.0  5.0  3.0  1.0  NaN NaN NaN NaN NaN
# tmIiMPl4IPa  8.0  6.0  3.0  8.0  3.0 NaN NaN NaN NaN
# mhnHqRqcjYU  8.0  6.0  6.0  NaN  NaN NaN NaN NaN NaN
# sZI1Oj9KBKy  8.0  6.0  5.0  3.0  NaN NaN NaN NaN NaN

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), gridspec_kw={'width_ratios': [1, 2]})
ratings.iloc[:, :-1].stack().value_counts().sort_index().plot.bar(
    ax=axes[0], title='ICLR 2021 Overall Ratings', xlabel='Rating', ylabel='Frequency')
ratings.iloc[:, :-1].mean(axis=1).mul(4).round().div(4).round(1).value_counts().sort_index().plot.bar(
    ax=axes[1], title='ICLR 2021 Ratings Averaged By Paper', xlabel='Avg Rating', ylabel='# Papers')
plt.tight_layout()
plt.savefig('asset/ratings_dist23.png', dpi=300, bbox_inches='tight')

# %%
data = {}
for keywords, rating in zip(df.keywords, ratings.iloc[:, :-1].mean(axis=1)):
    if (isinstance(keywords, float) and np.isnan(keywords)) or np.isnan(rating):
        continue
    for keyword in keywords.lower().replace('-', ' ').replace('networks', 'network').split(','):
        data.setdefault(keyword.strip(), []).append(rating)

t = pd.DataFrame({
    'Frequency': [min(len(v), 50) for v in data.values()], # clip to 50
    'AverageRating': [np.mean(v) for v in data.values()],
    'Keyword': list(data.keys())
}).query('Frequency>9')
t.plot.scatter(x='Frequency', y='AverageRating', figsize=(16, 12))

for i in range(len(t)):
     plt.text(t.Frequency.iloc[i], t.AverageRating.iloc[i], t.Keyword.iloc[i], 
              horizontalalignment='left', 
              size='small', color='black', alpha=0.6)

plt.tight_layout()
plt.savefig('asset/keyword_ratings23.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Top 50 Papers

# %%
comb_df = pd.DataFrame({
    'AvgRating': ratings.iloc[:, :-1].mean(axis=1).round(2),
    'Title': '[' + df['title'] + ']' + '(' + df['link'] + ')',
    'Ratings': ratings.iloc[:, :-1].apply(lambda x: ', '.join(x.dropna().astype(int).astype(str).values), axis=1),
    'Decision': ratings.iloc[:, -1],
})

comb_df = comb_df.sort_values('AvgRating', ascending=False).reset_index(drop=True)
comb_df.index += 1
comb_df.index.name = 'Rank'
comb_df.head(50)
# Out:
#       AvgRating                                              Title  \
# Rank
# 1          8.67  [Git Re-Basin: Merging Models modulo Permutati...
# 2          8.67  [Rethinking the Expressive Power of GNNs via G...
# 3          8.50  [DEP-RL: Embodied Exploration for Reinforcemen...
# 4          8.50  [Graph Neural Networks for Link Prediction wit...
# 5          8.50  [Revisiting the Entropy Semiring for Neural Sp...
# 6          8.50  [Emergence of Maps in the Memories of Blind Na...
# 7          8.25  [Understanding Ensemble, Knowledge Distillatio...
# 8          8.00  [Evaluating Long-Term Memory in 3D Mazes](http...
# 9          8.00  [Agree to Disagree: Diversity through Disagree...
# 10         8.00  [Relative representations enable zero-shot lat...
# 11         8.00  [Dr.Spider: A Diagnostic Evaluation Benchmark ...
# 12         8.00  [Can We Find Nash Equilibria at a Linear Rate ...
# 13         8.00  [Universal Few-shot Learning of Dense Predicti...
# 14         8.00  [The Lie Derivative for Measuring Learned Equi...
# 15         8.00  [Fast Nonlinear Vector Quantile Regression](ht...
# 16         8.00  [Targeted Hyperparameter Optimization with Lex...
# 17         8.00  [A Call to Reflect on Evaluation Practices for...
# 18         8.00  [Generating Diverse Cooperative Agents by Lear...
# 19         8.00  [Minimum Variance Unbiased N:M Sparsity for th...
# 20         8.00  [Benchmarking Deformable Object Manipulation w...
# 21         8.00  [Conditional Antibody Design as 3D Equivariant...
# 22         8.00  [ReAct: Synergizing Reasoning and Acting in La...
# 23         8.00  [Asymptotic Instance-Optimal Algorithms for In...
# 24         8.00  [Aligning Model and Macaque Inferior Temporal ...
# 25         8.00  [Martingale Posterior Neural Processes](https:...
# 26         8.00  [DreamFusion: Text-to-3D using 2D Diffusion](h...
# 27         8.00  [Sign and Basis Invariant Networks for Spectra...
# 28         8.00  [Scaling Up Probabilistic Circuits by Latent V...
# 29         8.00  [Self-Stabilization: The Implicit Bias of Grad...
# 30         8.00  [Learning a Data-Driven Policy Network for Pre...
# 31         8.00  [Mastering the Game of No-Press Diplomacy via ...
# 32         8.00  [Confidential-PROFITT: Confidential PROof of F...
# 33         8.00  [Strong inductive biases provably prevent harm...
# 34         8.00  [Transformers Learn Shortcuts to Automata](htt...
# 35         8.00  [What learning algorithm is in-context learnin...
# 36         8.00  [Robust Scheduling with GFlowNets](https://ope...
# 37         8.00  [FedExP: Speeding up Federated Averaging via E...
# 38         8.00  [Generate rather than Retrieve: Large Language...
# 39         8.00  [Geometric Networks Induced by Energy Constrai...
# 40         8.00  [AudioGen: Textually Guided Audio Generation](...
# 41         8.00  [Betty: An Automatic Differentiation Library f...
# 42         7.75  [DiffEdit: Diffusion-based semantic image edit...
# 43         7.75  [Flow Matching for Generative Modeling](https:...
# 44         7.75  [On the duality between contrastive and non-co...
# 45         7.67  [GPViT: A High Resolution Non-Hierarchical Vis...
# 46         7.60  [BigVGAN: A Universal Neural Vocoder with Larg...
# 47         7.60  [Selection-Inference: Exploiting Large Languag...
# 48         7.60  [CROM: Continuous Reduced-Order Modeling of PD...
# 49         7.60  [Exponential Generalization Bounds with Near-O...
# 50         7.50  [Concept-level Debugging of Part-Prototype Net...
#
#              Ratings  Decision
# Rank
# 1           8, 8, 10       NaN
# 2           8, 8, 10       NaN
# 3        8, 8, 8, 10       NaN
# 4        10, 8, 8, 8       NaN
# 5       10, 6, 8, 10       NaN
# 6        10, 8, 8, 8       NaN
# 7       5, 10, 10, 8       NaN
# 8            8, 8, 8       NaN
# 9         8, 8, 8, 8       NaN
# 10          8, 6, 10       NaN
# 11        8, 8, 8, 8       NaN
# 12        8, 8, 8, 8       NaN
# 13          6, 8, 10       NaN
# 14           8, 8, 8       NaN
# 15           8, 8, 8       NaN
# 16           8, 8, 8       NaN
# 17          6, 10, 8       NaN
# 18        8, 8, 8, 8       NaN
# 19           8, 8, 8       NaN
# 20           8, 8, 8       NaN
# 21        8, 8, 8, 8       NaN
# 22           8, 8, 8       NaN
# 23    6, 8, 10, 8, 8       NaN
# 24           8, 8, 8       NaN
# 25           8, 8, 8       NaN
# 26        8, 8, 8, 8       NaN
# 27        8, 8, 8, 8       NaN
# 28           8, 8, 8       NaN
# 29           8, 8, 8       NaN
# 30           8, 8, 8       NaN
# 31           8, 8, 8       NaN
# 32           8, 8, 8       NaN
# 33           8, 8, 8       NaN
# 34          6, 10, 8       NaN
# 35           8, 8, 8       NaN
# 36        8, 8, 8, 8       NaN
# 37           8, 8, 8       NaN
# 38       6, 8, 10, 8       NaN
# 39       10, 8, 6, 8       NaN
# 40        8, 8, 8, 8       NaN
# 41       8, 10, 6, 8       NaN
# 42       10, 8, 5, 8       NaN
# 43       5, 8, 8, 10       NaN
# 44       10, 8, 5, 8       NaN
# 45          10, 5, 8       NaN
# 46     6, 8, 8, 8, 8       NaN
# 47     8, 6, 8, 8, 8       NaN
# 48     8, 8, 8, 6, 8       NaN
# 49     8, 8, 8, 6, 8       NaN
# 50        8, 8, 8, 6       NaN

# %%
with open('ranked_papers.md', 'w', encoding='utf8') as f:
    comb_df.to_markdown(f)
